# %% [markdown]
# # Reaction Energy Profile
#
# This notebook demonstrates one stage of the Quantum ALD workflow. Core logic lives in `src/quantum_ald`.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / 'src'))

from quantum_ald import plot_energy_profile

energies = {
    'HF': {'R': 0.0, 'TS': 0.50, 'P': -0.20},
    'VQE': {'R': 0.0, 'TS': 0.48, 'P': -0.18},
}
plot_energy_profile(energies, Path.cwd().parent / 'results' / 'figures' / 'energy_profile.png')

# %% [markdown]
# ## Notes
#
# Run this notebook after installing the relevant optional dependencies.
