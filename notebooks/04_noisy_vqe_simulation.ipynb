# %% [markdown]
# # Noisy VQE Simulation Setup
#
# This notebook demonstrates one stage of the Quantum ALD workflow. Core logic lives in `src/quantum_ald`.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / 'src'))

from quantum_ald import carbon_nanotube_noise, NoiseModel

noise_model = carbon_nanotube_noise(t1=1.0, t2=0.5)
print(noise_model)
custom = NoiseModel('depolarizing-demo')
custom.add_depolarizing(0.01)
print(custom.params)

# %% [markdown]
# ## Notes
#
# Run this notebook after installing the relevant optional dependencies.
